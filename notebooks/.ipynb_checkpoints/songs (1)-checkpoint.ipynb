# %% [markdown]
# # Music Genre Classification using Machine Learning

# %% [markdown]
#  Use machine learning to train a model to classify audio tracks into genres. According to their “research” a machine learning model should be able to label the tracks into genres more accurately.

# %%
# import visualisation libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/Machine_learning')
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/Machine_learning

# %% [markdown]
# # Read and Explore the Data

# %%
# Read and preview data
songs_data = pd.read_csv('Data/songs_data.csv')
songs_data.head()
# Out:
#                  track_id                    track_name   track_artist  \
# 0  6ho0GyrWZN3mhi9zVRW7xi                     Losing It         FISHER
# 1  4bYJKHG6KLdGzHQRJMaFc8        Rock And Roll All Nite           KISS
# 2  1VGlMYqPO1LHyclvfIMvWI  Snälla bli min (Hjalm Remix)  Robin Lukovic
# 3  6BbINUfGabVyiNFJpQXn3x                        Wicked         Future
# 4  1Ly0ssAgeM7YqdHptao8Oe                      Paranoid  Black Sabbath
#
#    track_popularity genre  danceability  energy  key  loudness  mode  \
# 0                79   edm         0.760   0.964    2    -5.844     1
# 1                 3  rock         0.581   0.831    1    -8.045     1
# 2                 0   edm         0.661   0.760    8    -4.769     1
# 3                62   rap         0.718   0.679   11    -5.899     0
# 4                15  rock         0.426   0.619    4   -11.501     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0576      0.001820           0.70000    0.0974    0.641  125.000
# 1       0.1070      0.045800           0.00000    0.0782    0.885  144.684
# 2       0.0268      0.000406           0.04070    0.6110    0.439   99.993
# 3       0.0706      0.001910           0.01040    0.3850    0.205  157.970
# 4       0.0722      0.000084           0.00239    0.1700    0.382  162.721
#
#    duration_ms
# 0       248036
# 1       168160
# 2       271238
# 3       173347
# 4       168440

# %%
# shape of the data
songs_data.shape
# Out:
# (28396, 17)

# %%
songs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28396 entries, 0 to 28395
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          28396 non-null  object
#  1   track_name        28392 non-null  object
#  2   track_artist      28392 non-null  object
#  3   track_popularity  28396 non-null  int64
#  4   genre             28396 non-null  object
#  5   danceability      28396 non-null  float64
#  6   energy            28396 non-null  float64
#  7   key               28396 non-null  int64
#  8   loudness          28396 non-null  float64
#  9   mode              28396 non-null  int64
#  10  speechiness       28396 non-null  float64
#  11  acousticness      28396 non-null  float64
#  12  instrumentalness  28396 non-null  float64
#  13  liveness          28396 non-null  float64
#  14  valence           28396 non-null  float64
#  15  tempo             28396 non-null  float64
#  16  duration_ms       28396 non-null  int64
# dtypes: float64(9), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
# summary statistics for all the data

songs_data.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      28396.000000  28396.000000  28396.000000  28396.000000
# mean          39.336104      0.653386      0.698387      5.368256
# std           23.706486      0.145799      0.183484      3.613898
# min            0.000000      0.000000      0.000175      0.000000
# 25%           21.000000      0.561000      0.579000      2.000000
# 50%           42.000000      0.670000      0.722000      6.000000
# 75%           58.000000      0.760000      0.843000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  28396.000000  28396.000000  28396.000000  28396.000000
# mean      -6.817541      0.565397      0.107990      0.177263
# std        3.036443      0.495714      0.102623      0.222908
# min      -46.448000      0.000000      0.000000      0.000000
# 25%       -8.309000      0.000000      0.041000      0.014400
# 50%       -6.262000      1.000000      0.062700      0.079700
# 75%       -4.708750      1.000000      0.133000      0.260000
# max        1.275000      1.000000      0.918000      0.994000
#
#        instrumentalness      liveness       valence         tempo  \
# count      28396.000000  28396.000000  28396.000000  28396.000000
# mean           0.091143      0.190986      0.510434    120.955390
# std            0.232566      0.156015      0.234309     26.957635
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.092600      0.329000     99.972000
# 50%            0.000021      0.127000      0.512000    121.993000
# 75%            0.006573      0.249000      0.695000    133.999500
# max            0.994000      0.996000      0.991000    239.440000
#
#          duration_ms
# count   28396.000000
# mean   226575.367094
# std     61076.581384
# min      4000.000000
# 25%    187766.500000
# 50%    216921.000000
# 75%    254965.500000
# max    517810.000000

# %%
def identify_low_variance_features(df, std_threshold):
    """
    This definition can be used to identify features with low varaince

    @param df pandas DataFrame
    @param std_threshold int

    @return a list of features that have low variance
    """

    std_df = pd.DataFrame(df.std()).rename(columns = {0: 'standard_deviation'})

    low_var_features = list(std_df[std_df['standard_deviation'] < std_threshold].index)

    print("number of low variance features:", len(low_var_features))
    print("low variance features:", low_var_features)

    return low_var_features

# %%
# identify features with low std
identify_low_variance_features(songs_data, std_threshold=0.01)
# Out:
# number of low variance features: 0
# low variance features: []
# <ipython-input-7-fdc5b3841a8b>:11: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   std_df = pd.DataFrame(df.std()).rename(columns = {0: 'standard_deviation'})
# []

# %% [markdown]
# ## Handling Missing Data

# %%
# Identify missing data
songs_data.isnull().sum()
# Out:
# track_id            0
# track_name          4
# track_artist        4
# track_popularity    0
# genre               0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# dtype: int64

# %%
# Check which rows are missing in 'track_artist' column
songs_data[songs_data.track_artist.isnull()]
# Out:
#                      track_id track_name track_artist  track_popularity  \
# 16265  5TTzhRSWQS4Yu8xTgAuq6D        NaN          NaN                 0
# 16995  5cjecvX0CmC9gK0Laf5EMQ        NaN          NaN                 0
# 25483  69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
# 27825  3VKFip3OdAvv4OfNTgFWeQ        NaN          NaN                 0
#
#        genre  danceability  energy  key  loudness  mode  speechiness  \
# 16265    rap         0.465   0.820   10    -5.907     0       0.3070
# 16995    rap         0.678   0.659   11    -5.364     0       0.3190
# 25483    rap         0.714   0.821    6    -7.635     1       0.1760
# 27825  latin         0.675   0.919   11    -6.075     0       0.0366
#
#        acousticness  instrumentalness  liveness  valence    tempo  duration_ms
# 16265        0.0963           0.00000    0.0888    0.505   86.839       206465
# 16995        0.0534           0.00000    0.5530    0.191  146.153       202235
# 25483        0.0410           0.00000    0.1160    0.649   95.999       282707
# 27825        0.0606           0.00653    0.1030    0.726   97.017       252773

# %%
# Check which rows are missing in 'track_name' column
songs_data[songs_data.track_name.isnull()]
# Out:
#                      track_id track_name track_artist  track_popularity  \
# 16265  5TTzhRSWQS4Yu8xTgAuq6D        NaN          NaN                 0
# 16995  5cjecvX0CmC9gK0Laf5EMQ        NaN          NaN                 0
# 25483  69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
# 27825  3VKFip3OdAvv4OfNTgFWeQ        NaN          NaN                 0
#
#        genre  danceability  energy  key  loudness  mode  speechiness  \
# 16265    rap         0.465   0.820   10    -5.907     0       0.3070
# 16995    rap         0.678   0.659   11    -5.364     0       0.3190
# 25483    rap         0.714   0.821    6    -7.635     1       0.1760
# 27825  latin         0.675   0.919   11    -6.075     0       0.0366
#
#        acousticness  instrumentalness  liveness  valence    tempo  duration_ms
# 16265        0.0963           0.00000    0.0888    0.505   86.839       206465
# 16995        0.0534           0.00000    0.5530    0.191  146.153       202235
# 25483        0.0410           0.00000    0.1160    0.649   95.999       282707
# 27825        0.0606           0.00653    0.1030    0.726   97.017       252773

# %%
# drop rows with missing data

songs_data = songs_data.dropna(inplace=False)

# %% [markdown]
# ## Handling Duplicates

# %%
# check if the data has any duplicates

songs_data[songs_data.duplicated(keep=False)]

# this shows two rows that are duplicated
# Out:
#                      track_id                                track_name  \
# 1033   2CZFVWvkIatZGqHJ9IcpzE                                 Parachute
# 1326   4suDPyEfKYtqDR2OGblbTi  9と4分の3番線で君を待つ (Run Away) - Japanese Ver.
# 1483   6GbWNeR3P9MTCmSyPVHgb1                                     Taste
# 1546   1BINQwBuKPKhpDyXipBXLl                              Fly By Night
# 1744   5ceEaDSTtQR6HQ9yfEB6Sj                  Yamamoto - KMN Street EP
# ...                       ...                                       ...
# 27122  7DuLZ8HdkbJsFSIBJTYV9U                               Grasshopper
# 27380  35rnikz5NAOTvdc4gYzJFN                                    Sieben
# 27911  2lWfuwRnN6aSk50TPx6eCk                              If The World
# 28132  4lqEFIB9YZl8BwR99L5H3b   In My Room (feat. Ty Dolla $ign & Tyga)
# 28208  1dF5Y2dd7Wm4wZKvVjWBpr                          1st of Tha Month
#
#                track_artist  track_popularity genre  danceability  energy  \
# 1033                NSTASIA                37   r&b         0.814  0.4810
# 1326    TOMORROW X TOGETHER                48   pop         0.630  0.7870
# 1483                   Rhye                58   pop         0.768  0.4290
# 1546                   Rush                 0  rock         0.495  0.7790
# 1744                   Noah                40   rap         0.781  0.7050
# ...                     ...               ...   ...           ...     ...
# 27122            Agnes Obel                35   pop         0.734  0.0772
# 27380       Subway To Sally                41   pop         0.453  0.9860
# 27911         Guns N' Roses                 2  rock         0.645  0.7400
# 28132               Mustard                61   rap         0.745  0.8690
# 28208  Bone Thugs-N-Harmony                64   rap         0.729  0.5810
#
#        key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 1033     5    -6.448     0       0.1010       0.53000          0.000006
# 1326     1    -4.302     1       0.1030       0.00489          0.000000
# 1483     1    -9.401     1       0.0955       0.87500          0.419000
# 1546     7    -6.678     1       0.0706       0.04570          0.000200
# 1744     7    -4.821     0       0.0974       0.37700          0.000000
# ...    ...       ...   ...          ...           ...               ...
# 27122    2   -19.600     1       0.0544       0.84600          0.950000
# 27380    9    -1.853     0       0.1140       0.00354          0.000000
# 27911    7    -9.414     1       0.0528       0.00542          0.023900
# 28132    6    -4.375     1       0.0444       0.00193          0.000000
# 28208    5    -8.235     0       0.1800       0.07770          0.000004
#
#        liveness  valence    tempo  duration_ms
# 1033     0.1290    0.573  119.008       188962
# 1326     0.1340    0.466  128.997       211867
# 1483     0.1150    0.415  104.026       225600
# 1546     0.0813    0.545  139.076       201413
# 1744     0.1640    0.276   93.973       188936
# ...         ...      ...      ...          ...
# 27122    0.0905    0.159  120.070       158360
# 27380    0.1770    0.284  161.928       206289
# 27911    0.1150    0.783  146.434       293507
# 28132    0.0799    0.814  104.015       168641
# 28208    0.6960    0.508   74.038       314680
#
# [80 rows x 17 columns]

# %%
# going to drop the first appearance of duplicated data

print("shape of data before dropping, with the duplicates:", songs_data.shape)

songs_data_cleaned = songs_data[~songs_data.duplicated()]

print("shape of data after dropping the duplictaes:", songs_data_cleaned.shape)
# we dropped one row of data
# Out:
# shape of data before dropping, with the duplicates: (28392, 17)
# shape of data after dropping the duplictaes: (28352, 17)

# %%
# Check if it worked
songs_data_cleaned[songs_data_cleaned.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [track_id, track_name, track_artist, track_popularity, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms]
# Index: []

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# We need to encode the types of genres to numbers

# %%
# Check which are the different genres we have
songs_data_cleaned.genre.unique()
# Out:
# array(['edm', 'rock', 'rap', 'latin', 'r&b', 'pop'], dtype=object)

# %%
# label_encoder object knows how to understand word labels.

label_encoder = preprocessing.LabelEncoder()

songs_data_cleaned['genre_encode']= label_encoder.fit_transform(songs_data_cleaned['genre'])

songs_data_cleaned['genre_encode'].unique()
# Out:
# <ipython-input-17-128956bfc074>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   songs_data_cleaned['genre_encode']= label_encoder.fit_transform(songs_data_cleaned['genre'])
# array([0, 5, 4, 1, 3, 2])

# %%
# Check if it worked
songs_data_cleaned
# Out:
#                      track_id                                  track_name  \
# 0      6ho0GyrWZN3mhi9zVRW7xi                                   Losing It
# 1      4bYJKHG6KLdGzHQRJMaFc8                      Rock And Roll All Nite
# 2      1VGlMYqPO1LHyclvfIMvWI                Snälla bli min (Hjalm Remix)
# 3      6BbINUfGabVyiNFJpQXn3x                                      Wicked
# 4      1Ly0ssAgeM7YqdHptao8Oe                                    Paranoid
# ...                       ...                                         ...
# 28391  639L1OUV4JRqnPHaQaziYO                                 Black Water
# 28392  4bQGI1roeSr8Q85on2tQNU                                  Lean On Me
# 28393  32gaGfRgDMrMtcpCqF078U                                 Morning Dew
# 28394  7At7pljkrkgjwy0utWu2xx                        eoh (Theis EZ Remix)
# 28395  6sYJuVcEu4gFHmeTLdHzRz  Bittersweet Symphony (feat. Emily Roberts)
#
#           track_artist  track_popularity genre  danceability  energy  key  \
# 0               FISHER                79   edm         0.760   0.964    2
# 1                 KISS                 3  rock         0.581   0.831    1
# 2        Robin Lukovic                 0   edm         0.661   0.760    8
# 3               Future                62   rap         0.718   0.679   11
# 4        Black Sabbath                15  rock         0.426   0.619    4
# ...                ...               ...   ...           ...     ...  ...
# 28391         Massface                35  rock         0.253   0.931   11
# 28392     Club Nouveau                 2   r&b         0.748   0.629    0
# 28393     Matt Quentin                58   pop         0.686   0.332    9
# 28394         Hallasen                33   edm         0.845   0.505   10
# 28395  GAMPER & DADONI                72   pop         0.676   0.582    9
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0        -5.844     1       0.0576      0.001820          0.700000    0.0974
# 1        -8.045     1       0.1070      0.045800          0.000000    0.0782
# 2        -4.769     1       0.0268      0.000406          0.040700    0.6110
# 3        -5.899     0       0.0706      0.001910          0.010400    0.3850
# 4       -11.501     0       0.0722      0.000084          0.002390    0.1700
# ...         ...   ...          ...           ...               ...       ...
# 28391    -3.093     1       0.0616      0.000595          0.002170    0.0978
# 28392    -8.420     1       0.0660      0.016800          0.000000    0.0991
# 28393   -11.759     1       0.0454      0.890000          0.342000    0.1070
# 28394    -5.481     1       0.0516      0.057500          0.000424    0.0335
# 28395    -7.580     1       0.1280      0.221000          0.006270    0.5150
#
#        valence    tempo  duration_ms  genre_encode
# 0       0.6410  125.000       248036             0
# 1       0.8850  144.684       168160             5
# 2       0.4390   99.993       271238             0
# 3       0.2050  157.970       173347             4
# 4       0.3820  162.721       168440             5
# ...        ...      ...          ...           ...
# 28391   0.3320  194.911       208077             5
# 28392   0.9190  182.448       294947             3
# 28393   0.0745   80.994       237037             2
# 28394   0.2050  125.037       143095             0
# 28395   0.4470  124.012       194618             2
#
# [28352 rows x 18 columns]

# %%
# Check the distribution of the target

sns.distplot(songs_data_cleaned.genre_encode);
# Out:
# <ipython-input-19-0b708c097f23>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(songs_data_cleaned.genre_encode);

# %% [markdown]
# ### Exploring the data after cleaned

# %%
# Correlation matrix
df = songs_data_cleaned
plt.figure(figsize=(20,12))
sns.heatmap(songs_data_cleaned.corr(numeric_only=True),annot=True, linewidth=2)
plt.tight_layout()

# %%
def identify_highly_correlated_features(df, correlation_threshold):
    """
    This definition can be used to identify highly correlated features

    @param df pandas DataFrame
    @param correlation_threshold int

    @return a DataFrame with highly correlated features
    """

    corr_matrix = df.corr(numeric_only = True).abs() # calculate the correlation matrix with
    high_corr_var = np.where(corr_matrix >= correlation_threshold) # identify variables that have correlations above defined threshold
    high_corr_var = [(corr_matrix.index[x], corr_matrix.columns[y], round(corr_matrix.iloc[x, y], 2))
                         for x, y in zip(*high_corr_var) if x != y and x < y] # identify pairs of highly correlated variables

    high_corr_var_df = pd.DataFrame(high_corr_var).rename(columns = {0: 'corr_feature',
                                                                     1: 'drop_feature',
                                                                     2: 'correlation_values'})


    if high_corr_var_df.empty:
        high_corr_var_df
    else:
        high_corr_var_df = high_corr_var_df.sort_values(by = 'correlation_values', ascending = False)

    return high_corr_var_df

# %%
identify_highly_correlated_features(songs_data_cleaned, correlation_threshold=0.9)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### @@@@@Selecting the feature for the ML model

# %%
# Drop the columns which are least correlated
df_cleaned = df.copy()

df_cleaned = df_cleaned.drop(['key', 'mode', 'liveness'], axis=1)

# %%
df_cleaned
# Out:
#                      track_id                                  track_name  \
# 0      6ho0GyrWZN3mhi9zVRW7xi                                   Losing It
# 1      4bYJKHG6KLdGzHQRJMaFc8                      Rock And Roll All Nite
# 2      1VGlMYqPO1LHyclvfIMvWI                Snälla bli min (Hjalm Remix)
# 3      6BbINUfGabVyiNFJpQXn3x                                      Wicked
# 4      1Ly0ssAgeM7YqdHptao8Oe                                    Paranoid
# ...                       ...                                         ...
# 28391  639L1OUV4JRqnPHaQaziYO                                 Black Water
# 28392  4bQGI1roeSr8Q85on2tQNU                                  Lean On Me
# 28393  32gaGfRgDMrMtcpCqF078U                                 Morning Dew
# 28394  7At7pljkrkgjwy0utWu2xx                        eoh (Theis EZ Remix)
# 28395  6sYJuVcEu4gFHmeTLdHzRz  Bittersweet Symphony (feat. Emily Roberts)
#
#           track_artist  track_popularity genre  danceability  energy  \
# 0               FISHER                79   edm         0.760   0.964
# 1                 KISS                 3  rock         0.581   0.831
# 2        Robin Lukovic                 0   edm         0.661   0.760
# 3               Future                62   rap         0.718   0.679
# 4        Black Sabbath                15  rock         0.426   0.619
# ...                ...               ...   ...           ...     ...
# 28391         Massface                35  rock         0.253   0.931
# 28392     Club Nouveau                 2   r&b         0.748   0.629
# 28393     Matt Quentin                58   pop         0.686   0.332
# 28394         Hallasen                33   edm         0.845   0.505
# 28395  GAMPER & DADONI                72   pop         0.676   0.582
#
#        loudness  speechiness  acousticness  instrumentalness  valence  \
# 0        -5.844       0.0576      0.001820          0.700000   0.6410
# 1        -8.045       0.1070      0.045800          0.000000   0.8850
# 2        -4.769       0.0268      0.000406          0.040700   0.4390
# 3        -5.899       0.0706      0.001910          0.010400   0.2050
# 4       -11.501       0.0722      0.000084          0.002390   0.3820
# ...         ...          ...           ...               ...      ...
# 28391    -3.093       0.0616      0.000595          0.002170   0.3320
# 28392    -8.420       0.0660      0.016800          0.000000   0.9190
# 28393   -11.759       0.0454      0.890000          0.342000   0.0745
# 28394    -5.481       0.0516      0.057500          0.000424   0.2050
# 28395    -7.580       0.1280      0.221000          0.006270   0.4470
#
#          tempo  duration_ms  genre_encode
# 0      125.000       248036             0
# 1      144.684       168160             5
# 2       99.993       271238             0
# 3      157.970       173347             4
# 4      162.721       168440             5
# ...        ...          ...           ...
# 28391  194.911       208077             5
# 28392  182.448       294947             3
# 28393   80.994       237037             2
# 28394  125.037       143095             0
# 28395  124.012       194618             2
#
# [28352 rows x 15 columns]

# %%
# Check the distribution of the features & the target
df_cleaned.hist(figsize=(10, 10));

# %% [markdown]
# ### Looking for outliers

# %%
# Specify the columns for box plots
columns = ['track_popularity','danceability', 'energy', 'loudness', 'speechiness',
           'acousticness', 'instrumentalness', 'valence', 'tempo',
           'duration_ms']

# Create subplots for each column
fig, axs = plt.subplots(nrows=len(columns), figsize=(10, 50))

# Generate box plots for each column
for i, column in enumerate(columns):
    sns.boxplot(x=df_cleaned[column], color='red', ax=axs[i])
    axs[i].set_title(column)

plt.tight_layout()
plt.show()

# %%
lista=['track_popularity','danceability', 'energy', 'loudness', 'speechiness',
           'acousticness', 'instrumentalness', 'valence','tempo',
           'duration_ms', 'genre_encode']
for column in lista:
    q1 = np.nanpercentile(df_cleaned[column], 25)
    q3 = np.nanpercentile(df_cleaned[column], 75)

    iqr = q3 - q1
    UB = q3 + 1.5 * iqr
    LB = q1 - 1.5 * iqr

    print("Column:", column)
    print("25th percentile:", q1)
    print("75th percentile:", q3)
    print("IQR:", iqr)
    print("Upper Bound (UB):", UB)
    print("Lower Bound (LB):", LB)

    outliers = df_cleaned[(df_cleaned[column] > UB) | (df_cleaned[column] < LB)]
    num_outliers = outliers.shape[0]

    print("Values above", UB, "and values below", LB, "are outliers")
    print("Number of outliers:", num_outliers)
    print()  # Adding an empty line for readability
# Out:
# Column: track_popularity
# 25th percentile: 21.0
# 75th percentile: 58.0
# IQR: 37.0
# Upper Bound (UB): 113.5
# Lower Bound (LB): -34.5
# Values above 113.5 and values below -34.5 are outliers
# Number of outliers: 0
#
# Column: danceability
# 25th percentile: 0.561
# 75th percentile: 0.76
# IQR: 0.19899999999999995
# Upper Bound (UB): 1.0585
# Lower Bound (LB): 0.2625000000000001
# Values above 1.0585 and values below 0.2625000000000001 are outliers
# Number of outliers: 257
#
# Column: energy
# 25th percentile: 0.579
# 75th percentile: 0.843
# IQR: 0.264
# Upper Bound (UB): 1.2389999999999999
# Lower Bound (LB): 0.18299999999999994
# Values above 1.2389999999999999 and values below 0.18299999999999994 are outliers
# Number of outliers: 222
#
# Column: loudness
# 25th percentile: -8.31025
# 75th percentile: -4.70875
# IQR: 3.6014999999999997
# Upper Bound (UB): 0.6934999999999993
# Lower Bound (LB): -13.712499999999999
# Values above 0.6934999999999993 and values below -13.712499999999999 are outliers
# Number of outliers: 837
#
# Column: speechiness
# 25th percentile: 0.041
# 75th percentile: 0.133
# IQR: 0.092
# Upper Bound (UB): 0.271
# Lower Bound (LB): -0.097
# Values above 0.271 and values below -0.097 are outliers
# Number of outliers: 2723
#
# Column: acousticness
# 25th percentile: 0.0143
# 75th percentile: 0.26
# IQR: 0.2457
# Upper Bound (UB): 0.6285499999999999
# Lower Bound (LB): -0.35425
# Values above 0.6285499999999999 and values below -0.35425 are outliers
# Number of outliers: 1911
#
# Column: instrumentalness
# 25th percentile: 0.0
# 75th percentile: 0.0065725
# IQR: 0.0065725
# Upper Bound (UB): 0.01643125
# Lower Bound (LB): -0.00985875
# Values above 0.01643125 and values below -0.00985875 are outliers
# Number of outliers: 6085
#
# Column: valence
# 25th percentile: 0.329
# 75th percentile: 0.695
# IQR: 0.36599999999999994
# Upper Bound (UB): 1.2439999999999998
# Lower Bound (LB): -0.21999999999999992
# Values above 1.2439999999999998 and values below -0.21999999999999992 are outliers
# Number of outliers: 0
#
# Column: tempo
# 25th percentile: 99.972
# 75th percentile: 133.999
# IQR: 34.027
# Upper Bound (UB): 185.0395
# Lower Bound (LB): 48.93149999999999
# Values above 185.0395 and values below 48.93149999999999 are outliers
# Number of outliers: 494
#
# Column: duration_ms
# 25th percentile: 187741.25
# 75th percentile: 254975.25
# IQR: 67234.0
# Upper Bound (UB): 355826.25
# Lower Bound (LB): 86890.25
# Values above 355826.25 and values below 86890.25 are outliers
# Number of outliers: 1197
#
# Column: genre_encode
# 25th percentile: 1.0
# 75th percentile: 4.0
# IQR: 3.0
# Upper Bound (UB): 8.5
# Lower Bound (LB): -3.5
# Values above 8.5 and values below -3.5 are outliers
# Number of outliers: 0

# %% [markdown]
# ## Building the ML Model

# %%
# define our feature and target
target = df_cleaned.genre_encode
features = df_cleaned.drop(['genre','genre_encode','track_id','track_name','track_artist'], axis = 1)

# %% [markdown]
# #### Scale of the features

# %%
scaler = MinMaxScaler()
scaler.fit(features)
features_scaled = scaler.transform(features)

features_scaled
# Out:
# array([[0.79      , 0.77314344, 0.9639937 , ..., 0.64682139, 0.52205145,
#         0.47495378],
#        [0.03      , 0.59104781, 0.83097042, ..., 0.89303734, 0.60425994,
#         0.31949553],
#        [0.        , 0.67243133, 0.75995799, ..., 0.44298688, 0.41761193,
#         0.52011055],
#        ...,
#        [0.58      , 0.69786368, 0.33188308, ..., 0.07517659, 0.33826428,
#         0.45354703],
#        [0.33      , 0.85961343, 0.50491336, ..., 0.20686176, 0.52220598,
#         0.27071291],
#        [0.72      , 0.68769074, 0.58192684, ..., 0.45105954, 0.51792516,
#         0.37098928]])

# %%
df_scaled = pd.DataFrame(features_scaled)
df_scaled
# Out:
#           0         1         2         3         4         5         6  \
# 0      0.79  0.773143  0.963994  0.850827  0.062745  0.001831  0.704225
# 1      0.03  0.591048  0.830970  0.804706  0.116558  0.046076  0.000000
# 2      0.00  0.672431  0.759958  0.873352  0.029194  0.000408  0.040946
# 3      0.62  0.730417  0.678944  0.849674  0.076906  0.001922  0.010463
# 4      0.15  0.433367  0.618933  0.732288  0.078649  0.000085  0.002404
# ...     ...       ...       ...       ...       ...       ...       ...
# 28347  0.35  0.257375  0.930988  0.908472  0.067102  0.000599  0.002183
# 28348  0.02  0.760936  0.628935  0.796848  0.071895  0.016901  0.000000
# 28349  0.58  0.697864  0.331883  0.726882  0.049455  0.895372  0.344064
# 28350  0.33  0.859613  0.504913  0.858433  0.056209  0.057847  0.000427
# 28351  0.72  0.687691  0.581927  0.814450  0.139434  0.222334  0.006308
#
#               7         8         9
# 0      0.646821  0.522051  0.474954
# 1      0.893037  0.604260  0.319496
# 2      0.442987  0.417612  0.520111
# 3      0.206862  0.659748  0.329591
# 4      0.385469  0.679590  0.320040
# ...         ...       ...       ...
# 28347  0.335015  0.814029  0.397184
# 28348  0.927346  0.761978  0.566254
# 28349  0.075177  0.338264  0.453547
# 28350  0.206862  0.522206  0.270713
# 28351  0.451060  0.517925  0.370989
#
# [28352 rows x 10 columns]

# %%
# the shape of the features data frame and the scaled features are the same
print(features.shape)
print(features_scaled.shape)
# Out:
# (28352, 10)
# (28352, 10)

# %% [markdown]
# # Random Forest Model

# %%
# split the song data into training and test data

X_train_scaled, X_test_scaled, y_train, y_test = train_test_split(features_scaled,
                                                                  target,
                                                                  test_size = 0.3,
                                                                  random_state = 8)

# %%
# print the shape of the training data

print("Training Data")
print("Shape of X_train", X_train_scaled.shape)
print("Shape of y_train", y_train.shape)
# Out:
# Training Data
# Shape of X_train (19846, 10)
# Shape of y_train (19846,)

# %%
type(X_train_scaled)
# Out:
# numpy.ndarray

# %%
# Import and Fit the Random Forest Model

clf_rf = RandomForestClassifier()

clf_rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier()

# %%
# Make predictions on unseen data

y_pred_rf = clf_rf.predict(X_test_scaled)
y_pred_rf
# Out:
# array([5, 4, 4, ..., 5, 4, 1])

# %%
print("first five predicted values:", y_pred_rf[0:5])
print("first five actual values:", list(y_test[0:5]))
# Out:
# first five predicted values: [5 4 4 0 2]
# first five actual values: [5, 2, 4, 1, 2]

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

print("accuracy:", round(accuracy_score(y_test, y_pred_rf), 2))
print("recall:", round(recall_score(y_test, y_pred_rf, average='macro'), 2))
print("precision:", round(precision_score(y_test, y_pred_rf, average='macro'), 2))
print("f1-score:", round(f1_score(y_test, y_pred_rf, average='macro'), 2))
# Out:
# accuracy: 0.57
# recall: 0.57
# precision: 0.56
# f1-score: 0.56

# %%
# plot confusion matrix

cm = confusion_matrix(y_test, y_pred_rf)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=clf_rf.classes_)

disp.plot()
plt.show()

# %%
# print classification report

print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70      1435
#            1       0.52      0.34      0.41      1264
#            2       0.44      0.44      0.44      1516
#            3       0.51      0.48      0.50      1357
#            4       0.59      0.70      0.64      1640
#            5       0.65      0.70      0.67      1294
#
#     accuracy                           0.57      8506
#    macro avg       0.56      0.57      0.56      8506
# weighted avg       0.56      0.57      0.56      8506

# %%
# Get feature importances
importances = clf_rf.feature_importances_

# Create a DataFrame to store feature names and importances
feature_importance_df = pd.DataFrame({'Feature': features.columns, 'Importance': importances})

# Sort the features by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from matplotlib.legend_handler import HandlerLine2D

train_results = []
test_results = []
list_nb_estimators = [5, 10, 15, 30, 45, 60, 80, 100]

for nb_estimators in list_nb_estimators:
    clf_rf = RandomForestClassifier(n_estimators=nb_estimators)
    clf_rf.fit(X_train_scaled, y_train)

    train_results.append(mean_squared_error(y_train, clf_rf.predict(X_train_scaled)))
    test_results.append(mean_squared_error(y_test, clf_rf.predict(X_test_scaled)))

line1, = plt.plot(list_nb_estimators, train_results, color="r", label="Training Score")
line2, = plt.plot(list_nb_estimators, test_results, color="g", label="Testing Score")

plt.legend(handler_map={line1: HandlerLine2D(numpoints=1)})
plt.ylabel('MSE')
plt.xlabel('n_estimators')
plt.show()

# %% [markdown]
# # XGBoost Model

# %%
# Import the required libraries
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# Create an instance of the XGBoost classifier
clf_xgb = XGBClassifier()

# Fit the classifier on the training data
clf_xgb.fit(X_train_scaled, y_train)

# Make predictions on unseen data
y_pred_xgb = clf_xgb.predict(X_test_scaled)

# Print the predicted values and actual values for the first five samples
print("First five predicted values:", y_pred_xgb[:5])
print("First five actual values:", list(y_test[:5]))

# Evaluate the performance of the model
print("Accuracy:", round(accuracy_score(y_test, y_pred_xgb), 2))
print("Recall:", round(recall_score(y_test, y_pred_xgb, average='macro'), 2))
print("Precision:", round(precision_score(y_test, y_pred_xgb, average='macro'), 2))
print("F1-Score:", round(f1_score(y_test, y_pred_xgb, average='macro'), 2))

# Plot the confusion matrix
cm = confusion_matrix(y_test, y_pred_xgb)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf_xgb.classes_)
disp.plot()
plt.show()

# Print the classification report
print(classification_report(y_test, y_pred_xgb))
# Out:
# First five predicted values: [5 4 4 2 2]
# First five actual values: [5, 2, 4, 1, 2]
# Accuracy: 0.57
# Recall: 0.57
# Precision: 0.57
# F1-Score: 0.57
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.71      1435
#            1       0.50      0.38      0.44      1264
#            2       0.43      0.45      0.44      1516
#            3       0.51      0.48      0.49      1357
#            4       0.61      0.69      0.65      1640
#            5       0.66      0.70      0.68      1294
#
#     accuracy                           0.57      8506
#    macro avg       0.57      0.57      0.57      8506
# weighted avg       0.57      0.57      0.57      8506

# %% [markdown]
# # Random forest with tuning

# %%
RandomForestClassifier(n_estimators=500)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
params = {'n_estimators':np.arange(100,500,100),
          'max_features':np.arange(0.1,1.0,0.2)
         }
